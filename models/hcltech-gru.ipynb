# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/final/HCLTECH.csv")

# %%
df.shape
# Out:
# (102, 83)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.set_index(df.columns[0], inplace=True)

# %%
# df = df.T

# %%
df
# Out:
#                    4-Jun        4-Sep        4-Dec        5-Mar        5-Jun  \
# 4-Mar
# 30.962500      37.312500    44.525002    42.994999    46.562500    48.687500
# 59.220000      59.220000    59.220000    59.220000    63.840000    63.840000
# 59.220000      59.220000    59.220000    59.220000    63.840000    63.840000
# 2231.960000  2231.960000  2231.960000  2231.960000  2796.140000  2796.140000
# 2231.960000  2231.960000  2231.960000  2231.960000  2796.140000  2796.140000
# ...                  ...          ...          ...          ...          ...
# 1962.145758  1962.145758  1962.145758  1962.145758  1962.145758  1962.145758
# 0.020000        6.340000     4.460000     2.520000     2.930000    -0.250000
# 1556.875000  1556.875000  1556.875000  1556.875000  1556.875000  1556.875000
# 97.480000      57.710000    90.750000    76.540000    76.760000    85.220000
# 59.180000      59.220000    59.300000    63.440000    63.630000    63.840000
#
#                    5-Sep        5-Dec        6-Mar        6-Jun        6-Sep  \
# 4-Mar
# 30.962500      56.907501    67.387497    81.775002    63.082500    68.775002
# 59.220000      63.840000    63.840000    64.690000    64.690000    64.690000
# 59.220000      63.840000    63.840000    64.690000    64.690000    64.690000
# 2231.960000  2796.140000  2796.140000  2511.180000  2511.180000  2511.180000
# 2231.960000  2796.140000  2796.140000  2511.180000  2511.180000  2511.180000
# ...                  ...          ...          ...          ...          ...
# 1962.145758  1962.145758  1962.145758  1962.145758  1962.145758  1962.145758
# 0.020000        3.140000     6.930000    -1.000000     6.380000     5.440000
# 1556.875000  1556.875000  1556.875000  1556.875000  1556.875000  1556.875000
# 97.480000      89.390000   277.790000   134.760000   136.450000   205.830000
# 59.180000      64.000000    64.330000    64.560000    64.690000    64.830000
#
#              ...    22-Mar    22-Jun        22-Sep        22-Dec    23-Mar  \
# 4-Mar        ...
# 30.962500    ...   1163.75    973.25    932.349976   1039.300049   1085.25
# 59.220000    ...    543.00    543.00    543.000000    543.000000    543.00
# 59.220000    ...    543.00    543.00    543.000000    543.000000    543.00
# 2231.960000  ...  42048.00  42048.00  42048.000000  42048.000000  40561.00
# 2231.960000  ...  42048.00  42048.00  42048.000000  42048.000000  40561.00
# ...          ...       ...       ...           ...           ...       ...
# 1962.145758  ...   3472.00   3488.00   3544.000000   4125.000000   3559.00
# 0.020000     ...    469.00    810.00    803.000000    929.000000    715.00
# 1556.875000  ...   3003.00   2678.00   2741.000000   3196.000000   2844.00
# 97.480000    ...   3003.00   2678.00   2741.000000   3196.000000   2844.00
# 59.180000    ...    543.00    543.00    543.000000    543.000000    543.00
#
#                    23-Jun        23-Sep        23-Dec        24-Mar  \
# 4-Mar
# 30.962500     1187.949951   1234.800049   1466.099976   1543.550049
# 59.220000      543.000000    543.000000    543.000000    543.000000
# 59.220000      543.000000    543.000000    543.000000    543.000000
# 2231.960000  40561.000000  40561.000000  40561.000000  38927.000000
# 2231.960000  40561.000000  40561.000000  40561.000000  38927.000000
# ...                   ...           ...           ...           ...
# 1962.145758   3409.000000   3950.000000   4391.000000   3706.000000
# 0.020000       813.000000    984.000000   1042.000000    943.000000
# 1556.875000   2596.000000   2966.000000   3349.000000   2763.000000
# 97.480000     2596.000000   2966.000000   3349.000000   2763.000000
# 59.180000      543.000000    543.000000    543.000000    543.000000
#
#                    24-Jun
# 4-Mar
# 30.962500     1459.599976
# 59.220000      543.000000
# 59.220000      543.000000
# 2231.960000  38927.000000
# 2231.960000  38927.000000
# ...                   ...
# 1962.145758   3401.000000
# 0.020000       922.000000
# 1556.875000   2479.000000
# 97.480000     2479.000000
# 59.180000      543.000000
#
# [102 rows x 81 columns]

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i+look_back])
        y.append(data[i+look_back])
    return np.array(X), np.array(y)

look_back = 9
X, y = create_sequences(closing_prices_scaled, look_back)

# %%
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(GRU(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 7s 1s/step - loss: 0.0399 - val_loss: 0.3434
# Epoch 2/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0155 - val_loss: 0.1601
# Epoch 3/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0078 - val_loss: 0.0630
# Epoch 4/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0108 - val_loss: 0.0424
# Epoch 5/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0097 - val_loss: 0.0492
# Epoch 6/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0057 - val_loss: 0.0657
# Epoch 7/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0038 - val_loss: 0.0823
# Epoch 8/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0036 - val_loss: 0.0860
# Epoch 9/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0044 - val_loss: 0.0730
# Epoch 10/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0039 - val_loss: 0.0512
# Epoch 11/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0024 - val_loss: 0.0315
# Epoch 12/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0015 - val_loss: 0.0210
# Epoch 13/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0022 - val_loss: 0.0186
# Epoch 14/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0023 - val_loss: 0.0188
# Epoch 15/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0019 - val_loss: 0.0191
# Epoch 16/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0020 - val_loss: 0.0203
# Epoch 17/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0019 - val_loss: 0.0226
# Epoch 18/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0017 - val_loss: 0.0237
# Epoch 19/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0022 - val_loss: 0.0229
# Epoch 20/50
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0019 - val_loss: 0.0212
# Epoch 21/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0016 - val_loss: 0.0199
# Epoch 22/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0018 - val_loss: 0.0196
# Epoch 23/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0015 - val_loss: 0.0200
# Epoch 24/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0015 - val_loss: 0.0215
# Epoch 25/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0013 - val_loss: 0.0234
# Epoch 26/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0016 - val_loss: 0.0239
# Epoch 27/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0017 - val_loss: 0.0239
# Epoch 28/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0018 - val_loss: 0.0231
# Epoch 29/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0015 - val_loss: 0.0218
# Epoch 30/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0016 - val_loss: 0.0211
# Epoch 31/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0016 - val_loss: 0.0211
# Epoch 32/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0019 - val_loss: 0.0215
# Epoch 33/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0017 - val_loss: 0.0216
# Epoch 34/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0016 - val_loss: 0.0217
# Epoch 35/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0021 - val_loss: 0.0211
# Epoch 36/50
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0016 - val_loss: 0.0203
# Epoch 37/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0015 - val_loss: 0.0203
# Epoch 38/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0016 - val_loss: 0.0203
# Epoch 39/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0016 - val_loss: 0.0201
# Epoch 40/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0017 - val_loss: 0.0201
# Epoch 41/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0016 - val_loss: 0.0205
# Epoch 42/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0015 - val_loss: 0.0217
# Epoch 43/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0020 - val_loss: 0.0219
# Epoch 44/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0014 - val_loss: 0.0211
# Epoch 45/50
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0014 - val_loss: 0.0201
# Epoch 46/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0016 - val_loss: 0.0196
# Epoch 47/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0016 - val_loss: 0.0195
# Epoch 48/50
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0017 - val_loss: 0.0206
# Epoch 49/50
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0014 - val_loss: 0.0215
# Epoch 50/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0014 - val_loss: 0.0219

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 47ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
y_train_scaled = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
full_closing_prices = scaler.inverse_transform(closing_prices_scaled)
all_predictions = np.concatenate([train_predictions, test_predictions], axis=0)

# %%
future_predictions = []
last_sequence = closing_prices_scaled[-look_back:]

# %%
num_future_predictions = 4
for _ in range(num_future_predictions):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred).reshape(look_back, 1)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
extended_predictions = np.concatenate([all_predictions, future_predictions])

# %%
plt.figure(figsize=(8,4))
plt.plot(full_closing_prices, color='blue', label='Observed Closing Prices')
plt.plot(np.arange(look_back, look_back + len(train_predictions)), train_predictions, color='orange', label='Train Predictions')
plt.plot(np.arange(look_back + len(train_predictions), look_back + len(train_predictions) + len(test_predictions)), test_predictions, color='red', label='Test Predictions')
plt.plot(np.arange(len(full_closing_prices), len(full_closing_prices) + num_future_predictions), future_predictions, color='green', linestyle='--', label='Future Predictions')
plt.axvline(x=len(full_closing_prices) - len(test_predictions), color='green', linestyle='--', label='Prediction Start')
plt.title('Closing Price Prediction for HCLTECH using GRU')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y_test_scaled, test_predictions)
mse = mean_squared_error(y_test_scaled, test_predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Mean Absolute Error (MAE): 193.67817798859375
# Mean Squared Error (MSE): 50359.67245892477
# Root Mean Squared Error (RMSE): 224.40960865997866
# Mean Absolute Percentage Error (MAPE): 16.799510641124023%

# %%
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Mean Absolute Percentage Error (MAPE): 16.799510641124023%
