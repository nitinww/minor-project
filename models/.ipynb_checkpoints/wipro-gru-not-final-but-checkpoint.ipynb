# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/final/WIPRO.csv")

# %%
df.shape
# Out:
# (104, 83)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.set_index(df.columns[0], inplace=True)

# %%
# df = df.T

# %%
df
# Out:
#                    Jun 4        Sep 4        Dec 4        Mar 5        Jun 5  \
# Mar 4
# 51.045002      59.861252    67.139999    84.240005    75.481880    86.208755
# 46.550000      46.550000    46.550000    46.550000   140.710000   140.710000
# 46.550000      46.550000    46.550000    46.550000   140.710000   140.710000
# 3461.040000  3461.040000  3461.040000  3461.040000  4751.730000  4751.730000
# 3461.040000  3461.040000  3461.040000  3461.040000  4751.730000  4751.730000
# ...                  ...          ...          ...          ...          ...
# 2341.161765  2341.161765  2341.161765  2341.161765  2341.161765  2341.161765
# 74.400000      59.800000    66.700000    70.000000    65.700000    62.100000
# 1829.364706  1829.364706  1829.364706  1829.364706  1829.364706  1829.364706
# 259.000000    326.800000   370.100000   376.500000   421.400000   404.900000
# 46.600000     139.700000   139.800000   140.400000   140.700000   141.000000
#
#                    Sep 5        Dec 5        Mar 6        Jun 6        Sep 6  \
# Mar 4
# 51.045002      83.576256   104.253754   125.932503   115.503754   118.102509
# 46.550000     140.710000   140.710000   285.150000   285.150000   285.150000
# 46.550000     140.710000   140.710000   285.150000   285.150000   285.150000
# 3461.040000  4751.730000  4751.730000  6135.300000  6135.300000  6135.300000
# 3461.040000  4751.730000  4751.730000  6135.300000  6135.300000  6135.300000
# ...                  ...          ...          ...          ...          ...
# 2341.161765  2341.161765  2341.161765  2341.161765  2341.161765  2341.161765
# 74.400000      82.400000    85.100000    90.400000    98.000000    91.800000
# 1829.364706  1829.364706  1829.364706  1829.364706  1829.364706  1829.364706
# 259.000000    453.000000   505.100000   657.500000   619.100000   665.200000
# 46.600000     283.000000   284.100000   285.200000   286.400000   286.900000
#
#              ...        Mar 22        Jun 22    Sep 22    Dec 22    Mar 23  \
# Mar 4        ...
# 51.045002    ...    591.900024    416.049988    394.25    392.75    365.25
# 46.550000    ...   1096.400000   1096.400000   1096.40   1096.40   1097.60
# 46.550000    ...   1096.400000   1096.400000   1096.40   1096.40   1097.60
# 3461.040000  ...  53254.300000  53254.300000  53254.30  53254.30  61101.50
# 3461.040000  ...  53254.300000  53254.300000  53254.30  53254.30  61101.50
# ...          ...           ...           ...       ...       ...       ...
# 2341.161765  ...   6089.500000   2943.700000   2955.60   3227.10   3142.50
# 74.400000    ...    610.700000    727.100000    672.70    814.00    878.40
# 1829.364706  ...   5478.800000   2216.600000   2282.90   2413.10   2264.10
# 259.000000   ...   5478.800000   2216.600000   2282.90   2413.10   2264.10
# 46.600000    ...   1096.400000   1096.500000   1097.10   1097.40   1097.60
#
#                    Jun 23        Sep 23        Dec 23        Mar 24  \
# Mar 4
# 51.045002      389.149994    406.049988    471.299988    480.100006
# 46.550000     1097.600000   1097.600000   1097.600000   1045.000000
# 46.550000     1097.600000   1097.600000   1097.600000   1045.000000
# 3461.040000  61101.500000  61101.500000  61101.500000  56736.900000
# 3461.040000  61101.500000  61101.500000  61101.500000  56736.900000
# ...                   ...           ...           ...           ...
# 2341.161765   3421.100000   2848.100000   2803.500000   3344.800000
# 74.400000      833.300000    786.800000    780.600000    898.200000
# 1829.364706   2587.800000   2061.300000   2022.900000   2446.600000
# 259.000000    2587.800000   2061.300000   2022.900000   2446.600000
# 46.600000     1097.800000   1044.400000   1044.800000   1045.000000
#
#                    Jun 24
# Mar 4
# 51.045002      514.849976
# 46.550000     1045.000000
# 46.550000     1045.000000
# 3461.040000  56736.900000
# 3461.040000  56736.900000
# ...                   ...
# 2341.161765   3280.900000
# 74.400000      906.300000
# 1829.364706   2374.600000
# 259.000000    2374.600000
# 46.600000     1046.000000
#
# [104 rows x 81 columns]

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i+look_back])
        y.append(data[i+look_back])
    return np.array(X), np.array(y)

look_back = 9
X, y = create_sequences(closing_prices_scaled, look_back)

# %%
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(GRU(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 8s 1s/step - loss: 0.0243 - val_loss: 0.1683
# Epoch 2/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0060 - val_loss: 0.0746
# Epoch 3/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0059 - val_loss: 0.0517
# Epoch 4/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0088 - val_loss: 0.0598
# Epoch 5/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0054 - val_loss: 0.0833
# Epoch 6/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0034 - val_loss: 0.1085
# Epoch 7/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0038 - val_loss: 0.1211
# Epoch 8/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0049 - val_loss: 0.1190
# Epoch 9/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0045 - val_loss: 0.1052
# Epoch 10/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0035 - val_loss: 0.0870
# Epoch 11/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0029 - val_loss: 0.0724
# Epoch 12/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0030 - val_loss: 0.0632
# Epoch 13/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0034 - val_loss: 0.0599
# Epoch 14/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0033 - val_loss: 0.0628
# Epoch 15/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0027 - val_loss: 0.0683
# Epoch 16/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0027 - val_loss: 0.0729
# Epoch 17/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0025 - val_loss: 0.0739
# Epoch 18/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0028 - val_loss: 0.0703
# Epoch 19/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0025 - val_loss: 0.0641
# Epoch 20/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0024 - val_loss: 0.0577
# Epoch 21/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0022 - val_loss: 0.0531
# Epoch 22/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0023 - val_loss: 0.0506
# Epoch 23/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0025 - val_loss: 0.0509
# Epoch 24/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0020 - val_loss: 0.0529
# Epoch 25/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0022 - val_loss: 0.0546
# Epoch 26/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0022 - val_loss: 0.0548
# Epoch 27/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0022 - val_loss: 0.0527
# Epoch 28/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0020 - val_loss: 0.0504
# Epoch 29/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0020 - val_loss: 0.0479
# Epoch 30/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0469
# Epoch 31/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0023 - val_loss: 0.0469
# Epoch 32/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0017 - val_loss: 0.0474
# Epoch 33/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0020 - val_loss: 0.0479
# Epoch 34/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0020 - val_loss: 0.0480
# Epoch 35/50
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0020 - val_loss: 0.0477
# Epoch 36/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0021 - val_loss: 0.0471
# Epoch 37/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0021 - val_loss: 0.0463
# Epoch 38/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0021 - val_loss: 0.0461
# Epoch 39/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0020 - val_loss: 0.0460
# Epoch 40/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0020 - val_loss: 0.0460
# Epoch 41/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0020 - val_loss: 0.0460
# Epoch 42/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0020 - val_loss: 0.0463
# Epoch 43/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0019 - val_loss: 0.0461
# Epoch 44/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0021 - val_loss: 0.0457
# Epoch 45/50
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0022 - val_loss: 0.0452
# Epoch 46/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0019 - val_loss: 0.0452
# Epoch 47/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0021 - val_loss: 0.0455
# Epoch 48/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0018 - val_loss: 0.0456
# Epoch 49/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0022 - val_loss: 0.0449
# Epoch 50/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0021 - val_loss: 0.0447

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
y_train_scaled = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
full_closing_prices = scaler.inverse_transform(closing_prices_scaled)
all_predictions = np.concatenate([train_predictions, test_predictions], axis=0)

# %%
future_predictions = []
last_sequence = closing_prices_scaled[-look_back:]

# %%
num_future_predictions = 4
for _ in range(num_future_predictions):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred).reshape(look_back, 1)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
extended_predictions = np.concatenate([all_predictions, future_predictions])

# %%
plt.figure(figsize=(8,4))
plt.plot(full_closing_prices, color='blue', label='Observed Closing Prices')
plt.plot(np.arange(look_back, look_back + len(train_predictions)), train_predictions, color='orange', label='Train Predictions')
plt.plot(np.arange(look_back + len(train_predictions), look_back + len(train_predictions) + len(test_predictions)), test_predictions, color='red', label='Test Predictions')
plt.plot(np.arange(len(full_closing_prices), len(full_closing_prices) + num_future_predictions), future_predictions, color='green', linestyle='--', label='Future Predictions')
plt.axvline(x=len(full_closing_prices) - len(test_predictions), color='green', linestyle='--', label='Prediction Start')
plt.title('Closing Price Prediction for WIPRO using GRU')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y_test_scaled, test_predictions)
mse = mean_squared_error(y_test_scaled, test_predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Mean Absolute Error (MAE): 120.03832295735675
# Mean Squared Error (MSE): 19660.369838740193
# Root Mean Squared Error (RMSE): 140.21544080000675
# Mean Absolute Percentage Error (MAPE): 24.65345668619495%
