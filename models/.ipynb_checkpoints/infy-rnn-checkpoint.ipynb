# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/final/INFY.csv")

# %%
df.shape
# Out:
# (102, 83)

# %%
df.set_index(df.columns[0], inplace=True)

# %%
# df = df.T

# %%
df
# Out:
#                                                4-Mar        4-Jun       4-Sep  \
# INFY
# Close                                      77.159378    86.314064   105.96875
# Equity Share Capital                       33.320000    33.320000    33.32000
# Total Share Capital                        33.320000    33.320000    33.32000
# Reserves and Surplus                     3220.110000  3220.110000  3220.11000
# Total Reserves and Surplus               3220.110000  3220.110000  3220.11000
# ...                                              ...          ...         ...
# Tax                                        50.000000    65.000000    78.50000
# P/L After Tax from Ordinary Activities    337.050000   394.470000   454.85000
# Net Profit/(Loss) For the Period          337.050000   394.470000   454.85000
# Equity Share Capital                       33.320000    33.430000   133.93000
# Reserves Excluding Revaluation Reserves  3220.110000  3695.780000  3937.53000
#
#                                                4-Dec        5-Mar  \
# INFY
# Close                                     130.731247   141.074997
# Equity Share Capital                       33.320000   135.290000
# Total Share Capital                        33.320000   135.290000
# Reserves and Surplus                     3220.110000  5106.440000
# Total Reserves and Surplus               3220.110000  5106.440000
# ...                                              ...          ...
# Tax                                        93.000000    88.800000
# P/L After Tax from Ordinary Activities    495.970000   513.900000
# Net Profit/(Loss) For the Period          495.970000   559.090000
# Equity Share Capital                      134.730000   135.290000
# Reserves Excluding Revaluation Reserves  4608.960000  5106.440000
#
#                                                5-Jun        5-Sep  \
# INFY
# Close                                     147.390625   157.206253
# Equity Share Capital                      135.290000   135.290000
# Total Share Capital                       135.290000   135.290000
# Reserves and Surplus                     5106.440000  5106.440000
# Total Reserves and Surplus               5106.440000  5106.440000
# ...                                              ...          ...
# Tax                                        79.000000    67.000000
# P/L After Tax from Ordinary Activities    523.850000   592.000000
# Net Profit/(Loss) For the Period          523.850000   592.000000
# Equity Share Capital                      135.710000   136.000000
# Reserves Excluding Revaluation Reserves  5729.350000  6269.000000
#
#                                                5-Dec        6-Mar  \
# INFY
# Close                                     187.303131   186.337494
# Equity Share Capital                      135.290000   138.000000
# Total Share Capital                       135.290000   138.000000
# Reserves and Surplus                     5106.440000  6759.000000
# Total Reserves and Surplus               5106.440000  6759.000000
# ...                                              ...          ...
# Tax                                        80.000000    77.000000
# P/L After Tax from Ordinary Activities    642.000000   664.000000
# Net Profit/(Loss) For the Period          642.000000   664.000000
# Equity Share Capital                      137.000000   138.000000
# Reserves Excluding Revaluation Reserves  7113.000000  6759.000000
#
#                                                6-Jun  ...        22-Mar  \
# INFY                                                  ...
# Close                                     192.434372  ...   1906.849976
# Equity Share Capital                      138.000000  ...   2103.000000
# Total Share Capital                       138.000000  ...   2103.000000
# Reserves and Surplus                     6759.000000  ...  66597.000000
# Total Reserves and Surplus               6759.000000  ...  66597.000000
# ...                                              ...  ...           ...
# Tax                                       104.000000  ...   1731.000000
# P/L After Tax from Ordinary Activities    805.000000  ...   5177.000000
# Net Profit/(Loss) For the Period          805.000000  ...   5177.000000
# Equity Share Capital                      138.000000  ...   2103.000000
# Reserves Excluding Revaluation Reserves  7690.000000  ...  67203.000000
#
#                                                22-Jun        22-Sep  \
# INFY
# Close                                     1461.900024   1413.449951
# Equity Share Capital                      2103.000000   2103.000000
# Total Share Capital                       2103.000000   2103.000000
# Reserves and Surplus                     66597.000000  66597.000000
# Total Reserves and Surplus               66597.000000  66597.000000
# ...                                               ...           ...
# Tax                                       2001.000000   2235.000000
# P/L After Tax from Ordinary Activities    4901.000000   6253.000000
# Net Profit/(Loss) For the Period          4901.000000   6253.000000
# Equity Share Capital                      2104.000000   2104.000000
# Reserves Excluding Revaluation Reserves  36730.231000  36730.231000
#
#                                                22-Dec        23-Mar  \
# INFY
# Close                                     1508.199951   1427.949951
# Equity Share Capital                      2103.000000   2074.000000
# Total Share Capital                       2103.000000   2074.000000
# Reserves and Surplus                     66597.000000  64793.000000
# Total Reserves and Surplus               66597.000000  64793.000000
# ...                                               ...           ...
# Tax                                       2085.000000   2053.000000
# P/L After Tax from Ordinary Activities    6210.000000   5904.000000
# Net Profit/(Loss) For the Period          6210.000000   5904.000000
# Equity Share Capital                      2091.000000   2074.000000
# Reserves Excluding Revaluation Reserves  36730.231000  65671.000000
#
#                                             23-Jun        23-Sep  \
# INFY
# Close                                     1335.500   1435.449951
# Equity Share Capital                      2074.000   2074.000000
# Total Share Capital                       2074.000   2074.000000
# Reserves and Surplus                     64793.000  64793.000000
# Total Reserves and Surplus               64793.000  64793.000000
# ...                                            ...           ...
# Tax                                       2190.000   2272.000000
# P/L After Tax from Ordinary Activities    5956.000   6245.000000
# Net Profit/(Loss) For the Period          5956.000   6245.000000
# Equity Share Capital                      2075.000   2075.000000
# Reserves Excluding Revaluation Reserves  36730.231  36730.231000
#
#                                                23-Dec        24-Mar     24-Jun
# INFY
# Close                                     1542.900024   1498.050049   1566.750
# Equity Share Capital                      2074.000000   2075.000000   2075.000
# Total Share Capital                       2074.000000   2075.000000   2075.000
# Reserves and Surplus                     64793.000000  79101.000000  79101.000
# Total Reserves and Surplus               64793.000000  79101.000000  79101.000
# ...                                               ...           ...        ...
# Tax                                       2324.000000   1934.000000   2360.000
# P/L After Tax from Ordinary Activities    6552.000000   8480.000000   5768.000
# Net Profit/(Loss) For the Period          6552.000000   8480.000000   5768.000
# Equity Share Capital                      2075.000000   2075.000000   2076.000
# Reserves Excluding Revaluation Reserves  36730.231000  36730.231000  36730.231
#
# [102 rows x 82 columns]

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i+look_back])
        y.append(data[i+look_back])
    return np.array(X), np.array(y)

look_back = 9
X, y = create_sequences(closing_prices_scaled, look_back)

# %%
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(SimpleRNN(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 517ms/step - loss: 0.0542 - val_loss: 0.1747
# Epoch 2/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0335 - val_loss: 0.6683
# Epoch 3/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0386 - val_loss: 0.3895
# Epoch 4/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0128 - val_loss: 0.1175
# Epoch 5/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0174 - val_loss: 0.0599
# Epoch 6/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0166 - val_loss: 0.0942
# Epoch 7/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0093 - val_loss: 0.1519
# Epoch 8/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0099 - val_loss: 0.1831
# Epoch 9/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.1294
# Epoch 10/50
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0070 - val_loss: 0.0814
# Epoch 11/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0060 - val_loss: 0.0605
# Epoch 12/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0070 - val_loss: 0.0525
# Epoch 13/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0064 - val_loss: 0.0585
# Epoch 14/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0053 - val_loss: 0.0694
# Epoch 15/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0050 - val_loss: 0.0777
# Epoch 16/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0069 - val_loss: 0.0728
# Epoch 17/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0056 - val_loss: 0.0520
# Epoch 18/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0055 - val_loss: 0.0382
# Epoch 19/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0044 - val_loss: 0.0315
# Epoch 20/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0051 - val_loss: 0.0356
# Epoch 21/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0032 - val_loss: 0.0454
# Epoch 22/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0042 - val_loss: 0.0606
# Epoch 23/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0031 - val_loss: 0.0692
# Epoch 24/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0047 - val_loss: 0.0607
# Epoch 25/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0043 - val_loss: 0.0431
# Epoch 26/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0024 - val_loss: 0.0299
# Epoch 27/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0035 - val_loss: 0.0278
# Epoch 28/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0034 - val_loss: 0.0295
# Epoch 29/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0038 - val_loss: 0.0337
# Epoch 30/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0021 - val_loss: 0.0447
# Epoch 31/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0027 - val_loss: 0.0494
# Epoch 32/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0026 - val_loss: 0.0497
# Epoch 33/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0028 - val_loss: 0.0464
# Epoch 34/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0027 - val_loss: 0.0388
# Epoch 35/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0024 - val_loss: 0.0308
# Epoch 36/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0019 - val_loss: 0.0295
# Epoch 37/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0017 - val_loss: 0.0319
# Epoch 38/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0018 - val_loss: 0.0381
# Epoch 39/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0018 - val_loss: 0.0451
# Epoch 40/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0029 - val_loss: 0.0402
# Epoch 41/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0026 - val_loss: 0.0314
# Epoch 42/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0027 - val_loss: 0.0282
# Epoch 43/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0025 - val_loss: 0.0311
# Epoch 44/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0024 - val_loss: 0.0367
# Epoch 45/50
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0018 - val_loss: 0.0397
# Epoch 46/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0019 - val_loss: 0.0391
# Epoch 47/50
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0018 - val_loss: 0.0364
# Epoch 48/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0019 - val_loss: 0.0317
# Epoch 49/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0244
# Epoch 50/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0023 - val_loss: 0.0204

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
y_train_scaled = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
full_closing_prices = scaler.inverse_transform(closing_prices_scaled)
all_predictions = np.concatenate([train_predictions, test_predictions], axis=0)

# %%
future_predictions = []
last_sequence = closing_prices_scaled[-look_back:]

# %%
num_future_predictions = 4
for _ in range(num_future_predictions):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred).reshape(look_back, 1)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
extended_predictions = np.concatenate([all_predictions, future_predictions])

# %%
plt.figure(figsize=(8,4))
plt.plot(full_closing_prices, color='blue', label='Observed Closing Prices')
plt.plot(np.arange(look_back, look_back + len(train_predictions)), train_predictions, color='orange', label='Train Predictions')
plt.plot(np.arange(look_back + len(train_predictions), look_back + len(train_predictions) + len(test_predictions)), test_predictions, color='red', label='Test Predictions')
plt.plot(np.arange(len(full_closing_prices), len(full_closing_prices) + num_future_predictions), future_predictions, color='green', linestyle='--', label='Future Predictions')
plt.axvline(x=len(full_closing_prices) - len(test_predictions), color='green', linestyle='--', label='Prediction Start')
plt.title('Closing Price Prediction for INFY using RNN')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
print("Performance metrics:")
mae = mean_absolute_error(y_test_scaled, test_predictions)
mse = mean_squared_error(y_test_scaled, test_predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Performance metrics:
# Mean Absolute Error (MAE): 233.44700522447914
# Mean Squared Error (MSE): 67714.73279707863
# Root Mean Squared Error (RMSE): 260.2205464545001
# Mean Absolute Percentage Error (MAPE): 15.416898328927523%
