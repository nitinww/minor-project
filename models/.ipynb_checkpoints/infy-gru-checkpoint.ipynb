# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/final/INFY.csv")

# %%
df.shape
# Out:
# (102, 83)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.set_index(df.columns[0], inplace=True)

# %%
# df = df.T

# %%
df
# Out:
#                    4-Jun       4-Sep        4-Dec        5-Mar        5-Jun  \
# 4-Mar
# 77.159378      86.314064   105.96875   130.731247   141.074997   147.390625
# 33.320000      33.320000    33.32000    33.320000   135.290000   135.290000
# 33.320000      33.320000    33.32000    33.320000   135.290000   135.290000
# 3220.110000  3220.110000  3220.11000  3220.110000  5106.440000  5106.440000
# 3220.110000  3220.110000  3220.11000  3220.110000  5106.440000  5106.440000
# ...                  ...         ...          ...          ...          ...
# 50.000000      65.000000    78.50000    93.000000    88.800000    79.000000
# 337.050000    394.470000   454.85000   495.970000   513.900000   523.850000
# 337.050000    394.470000   454.85000   495.970000   559.090000   523.850000
# 33.320000      33.430000   133.93000   134.730000   135.290000   135.710000
# 3220.110000  3695.780000  3937.53000  4608.960000  5106.440000  5729.350000
#
#                    5-Sep        5-Dec        6-Mar        6-Jun        6-Sep  \
# 4-Mar
# 77.159378     157.206253   187.303131   186.337494   192.434372   231.206253
# 33.320000     135.290000   135.290000   138.000000   138.000000   138.000000
# 33.320000     135.290000   135.290000   138.000000   138.000000   138.000000
# 3220.110000  5106.440000  5106.440000  6759.000000  6759.000000  6759.000000
# 3220.110000  5106.440000  5106.440000  6759.000000  6759.000000  6759.000000
# ...                  ...          ...          ...          ...          ...
# 50.000000      67.000000    80.000000    77.000000   104.000000   114.000000
# 337.050000    592.000000   642.000000   664.000000   805.000000   896.000000
# 337.050000    592.000000   642.000000   664.000000   805.000000   896.000000
# 33.320000     136.000000   137.000000   138.000000   138.000000   278.000000
# 3220.110000  6269.000000  7113.000000  6759.000000  7690.000000  8273.000000
#
#              ...        22-Mar        22-Jun        22-Sep        22-Dec  \
# 4-Mar        ...
# 77.159378    ...   1906.849976   1461.900024   1413.449951   1508.199951
# 33.320000    ...   2103.000000   2103.000000   2103.000000   2103.000000
# 33.320000    ...   2103.000000   2103.000000   2103.000000   2103.000000
# 3220.110000  ...  66597.000000  66597.000000  66597.000000  66597.000000
# 3220.110000  ...  66597.000000  66597.000000  66597.000000  66597.000000
# ...          ...           ...           ...           ...           ...
# 50.000000    ...   1731.000000   2001.000000   2235.000000   2085.000000
# 337.050000   ...   5177.000000   4901.000000   6253.000000   6210.000000
# 337.050000   ...   5177.000000   4901.000000   6253.000000   6210.000000
# 33.320000    ...   2103.000000   2104.000000   2104.000000   2091.000000
# 3220.110000  ...  67203.000000  36730.231000  36730.231000  36730.231000
#
#                    23-Mar     23-Jun        23-Sep        23-Dec  \
# 4-Mar
# 77.159378     1427.949951   1335.500   1435.449951   1542.900024
# 33.320000     2074.000000   2074.000   2074.000000   2074.000000
# 33.320000     2074.000000   2074.000   2074.000000   2074.000000
# 3220.110000  64793.000000  64793.000  64793.000000  64793.000000
# 3220.110000  64793.000000  64793.000  64793.000000  64793.000000
# ...                   ...        ...           ...           ...
# 50.000000     2053.000000   2190.000   2272.000000   2324.000000
# 337.050000    5904.000000   5956.000   6245.000000   6552.000000
# 337.050000    5904.000000   5956.000   6245.000000   6552.000000
# 33.320000     2074.000000   2075.000   2075.000000   2075.000000
# 3220.110000  65671.000000  36730.231  36730.231000  36730.231000
#
#                    24-Mar     24-Jun
# 4-Mar
# 77.159378     1498.050049   1566.750
# 33.320000     2075.000000   2075.000
# 33.320000     2075.000000   2075.000
# 3220.110000  79101.000000  79101.000
# 3220.110000  79101.000000  79101.000
# ...                   ...        ...
# 50.000000     1934.000000   2360.000
# 337.050000    8480.000000   5768.000
# 337.050000    8480.000000   5768.000
# 33.320000     2075.000000   2076.000
# 3220.110000  36730.231000  36730.231
#
# [102 rows x 81 columns]

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i+look_back])
        y.append(data[i+look_back])
    return np.array(X), np.array(y)

look_back = 9
X, y = create_sequences(closing_prices_scaled, look_back)

# %%
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(GRU(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 7s 1s/step - loss: 0.0498 - val_loss: 0.4481
# Epoch 2/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0167 - val_loss: 0.2229
# Epoch 3/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0068 - val_loss: 0.0969
# Epoch 4/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0105 - val_loss: 0.0618
# Epoch 5/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0117 - val_loss: 0.0682
# Epoch 6/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0083 - val_loss: 0.0927
# Epoch 7/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0047 - val_loss: 0.1219
# Epoch 8/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0046 - val_loss: 0.1445
# Epoch 9/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0055 - val_loss: 0.1482
# Epoch 10/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0053 - val_loss: 0.1359
# Epoch 11/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0048 - val_loss: 0.1135
# Epoch 12/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0039 - val_loss: 0.0872
# Epoch 13/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0037 - val_loss: 0.0636
# Epoch 14/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0027 - val_loss: 0.0476
# Epoch 15/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0030 - val_loss: 0.0390
# Epoch 16/50
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0031 - val_loss: 0.0369
# Epoch 17/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0027 - val_loss: 0.0374
# Epoch 18/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0024 - val_loss: 0.0389
# Epoch 19/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0023 - val_loss: 0.0397
# Epoch 20/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0021 - val_loss: 0.0391
# Epoch 21/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0018 - val_loss: 0.0370
# Epoch 22/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0018 - val_loss: 0.0350
# Epoch 23/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0017 - val_loss: 0.0338
# Epoch 24/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0018 - val_loss: 0.0337
# Epoch 25/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0018 - val_loss: 0.0342
# Epoch 26/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0017 - val_loss: 0.0346
# Epoch 27/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0021 - val_loss: 0.0345
# Epoch 28/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0341
# Epoch 29/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0020 - val_loss: 0.0339
# Epoch 30/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0019 - val_loss: 0.0336
# Epoch 31/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0020 - val_loss: 0.0334
# Epoch 32/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0017 - val_loss: 0.0330
# Epoch 33/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0017 - val_loss: 0.0326
# Epoch 34/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0021 - val_loss: 0.0323
# Epoch 35/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0018 - val_loss: 0.0319
# Epoch 36/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0018 - val_loss: 0.0316
# Epoch 37/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0018 - val_loss: 0.0315
# Epoch 38/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0017 - val_loss: 0.0314
# Epoch 39/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0016 - val_loss: 0.0314
# Epoch 40/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0017 - val_loss: 0.0311
# Epoch 41/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0020 - val_loss: 0.0306
# Epoch 42/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0021 - val_loss: 0.0305
# Epoch 43/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0017 - val_loss: 0.0308
# Epoch 44/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0016 - val_loss: 0.0308
# Epoch 45/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0018 - val_loss: 0.0306
# Epoch 46/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0016 - val_loss: 0.0301
# Epoch 47/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0016 - val_loss: 0.0298
# Epoch 48/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.0297
# Epoch 49/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0020 - val_loss: 0.0298
# Epoch 50/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0015 - val_loss: 0.0299

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 6ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
y_train_scaled = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
full_closing_prices = scaler.inverse_transform(closing_prices_scaled)
all_predictions = np.concatenate([train_predictions, test_predictions], axis=0)

# %%
future_predictions = []
last_sequence = closing_prices_scaled[-look_back:]

# %%
num_future_predictions = 4
for _ in range(num_future_predictions):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred).reshape(look_back, 1)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
extended_predictions = np.concatenate([all_predictions, future_predictions])

# %%
plt.figure(figsize=(8,4))
plt.plot(full_closing_prices, color='blue', label='Observed Closing Prices')
plt.plot(np.arange(look_back, look_back + len(train_predictions)), train_predictions, color='orange', label='Train Predictions')
plt.plot(np.arange(look_back + len(train_predictions), look_back + len(train_predictions) + len(test_predictions)), test_predictions, color='red', label='Test Predictions')
plt.plot(np.arange(len(full_closing_prices), len(full_closing_prices) + num_future_predictions), future_predictions, color='green', linestyle='--', label='Future Predictions')
plt.axvline(x=len(full_closing_prices) - len(test_predictions), color='green', linestyle='--', label='Prediction Start')
plt.title('Closing Price Prediction for INFY using GRU')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
print("Performance metrics:")
mae = mean_absolute_error(y_test_scaled, test_predictions)
mse = mean_squared_error(y_test_scaled, test_predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Performance metrics:
# Mean Absolute Error (MAE): 269.43572599635417
# Mean Squared Error (MSE): 96906.26514102727
# Root Mean Squared Error (RMSE): 311.2977114291515
# Mean Absolute Percentage Error (MAPE): 17.85934239874395%
