# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/WIPRO-imputated.csv")

# %%
df = pd.read_csv("../datasets/HCLTECH.csv")

# %%
df = pd.read_csv("../datasets/INFY.csv")

# %%
df = pd.read_csv("../datasets/TCS.csv")

# %%
df = df.set_index(df.columns[0])
df.shape
# Out:
# (18, 82)

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_dataset(df, look_back=10):
    X, Y = [], []
    for i in range(len(df) - look_back):
        X.append(df[i:i + look_back, 0])
        Y.append(df[i + look_back, 0])
    print(len(X))
    print(len(Y))
    return np.array(X), np.array(Y)

# %%
look_back = 4
X, Y = create_dataset(closing_prices_scaled, look_back)

X = np.reshape(X, (X.shape[0], X.shape[1], 1))
# Out:
# 77
# 77

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X, Y, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 77/77 - 4s - loss: 0.0343 - 4s/epoch - 57ms/step
# Epoch 2/100
# 77/77 - 0s - loss: 0.0134 - 329ms/epoch - 4ms/step
# Epoch 3/100
# 77/77 - 0s - loss: 0.0084 - 309ms/epoch - 4ms/step
# Epoch 4/100
# 77/77 - 0s - loss: 0.0063 - 328ms/epoch - 4ms/step
# Epoch 5/100
# 77/77 - 0s - loss: 0.0086 - 362ms/epoch - 5ms/step
# Epoch 6/100
# 77/77 - 0s - loss: 0.0070 - 373ms/epoch - 5ms/step
# Epoch 7/100
# 77/77 - 0s - loss: 0.0108 - 326ms/epoch - 4ms/step
# Epoch 8/100
# 77/77 - 0s - loss: 0.0050 - 394ms/epoch - 5ms/step
# Epoch 9/100
# 77/77 - 0s - loss: 0.0065 - 303ms/epoch - 4ms/step
# Epoch 10/100
# 77/77 - 0s - loss: 0.0053 - 337ms/epoch - 4ms/step
# Epoch 11/100
# 77/77 - 0s - loss: 0.0086 - 389ms/epoch - 5ms/step
# Epoch 12/100
# 77/77 - 0s - loss: 0.0065 - 380ms/epoch - 5ms/step
# Epoch 13/100
# 77/77 - 0s - loss: 0.0061 - 388ms/epoch - 5ms/step
# Epoch 14/100
# 77/77 - 0s - loss: 0.0053 - 289ms/epoch - 4ms/step
# Epoch 15/100
# 77/77 - 0s - loss: 0.0070 - 273ms/epoch - 4ms/step
# Epoch 16/100
# 77/77 - 0s - loss: 0.0067 - 275ms/epoch - 4ms/step
# Epoch 17/100
# 77/77 - 0s - loss: 0.0061 - 271ms/epoch - 4ms/step
# Epoch 18/100
# 77/77 - 0s - loss: 0.0079 - 281ms/epoch - 4ms/step
# Epoch 19/100
# 77/77 - 0s - loss: 0.0064 - 306ms/epoch - 4ms/step
# Epoch 20/100
# 77/77 - 0s - loss: 0.0071 - 304ms/epoch - 4ms/step
# Epoch 21/100
# 77/77 - 0s - loss: 0.0041 - 281ms/epoch - 4ms/step
# Epoch 22/100
# 77/77 - 0s - loss: 0.0048 - 289ms/epoch - 4ms/step
# Epoch 23/100
# 77/77 - 0s - loss: 0.0053 - 269ms/epoch - 3ms/step
# Epoch 24/100
# 77/77 - 0s - loss: 0.0063 - 272ms/epoch - 4ms/step
# Epoch 25/100
# 77/77 - 0s - loss: 0.0065 - 283ms/epoch - 4ms/step
# Epoch 26/100
# 77/77 - 0s - loss: 0.0047 - 265ms/epoch - 3ms/step
# Epoch 27/100
# 77/77 - 0s - loss: 0.0050 - 196ms/epoch - 3ms/step
# Epoch 28/100
# 77/77 - 0s - loss: 0.0052 - 252ms/epoch - 3ms/step
# Epoch 29/100
# 77/77 - 0s - loss: 0.0044 - 370ms/epoch - 5ms/step
# Epoch 30/100
# 77/77 - 0s - loss: 0.0057 - 315ms/epoch - 4ms/step
# Epoch 31/100
# 77/77 - 0s - loss: 0.0059 - 309ms/epoch - 4ms/step
# Epoch 32/100
# 77/77 - 0s - loss: 0.0050 - 306ms/epoch - 4ms/step
# Epoch 33/100
# 77/77 - 0s - loss: 0.0075 - 364ms/epoch - 5ms/step
# Epoch 34/100
# 77/77 - 0s - loss: 0.0037 - 379ms/epoch - 5ms/step
# Epoch 35/100
# 77/77 - 0s - loss: 0.0039 - 289ms/epoch - 4ms/step
# Epoch 36/100
# 77/77 - 0s - loss: 0.0055 - 286ms/epoch - 4ms/step
# Epoch 37/100
# 77/77 - 0s - loss: 0.0049 - 273ms/epoch - 4ms/step
# Epoch 38/100
# 77/77 - 0s - loss: 0.0053 - 275ms/epoch - 4ms/step
# Epoch 39/100
# 77/77 - 0s - loss: 0.0037 - 273ms/epoch - 4ms/step
# Epoch 40/100
# 77/77 - 0s - loss: 0.0042 - 283ms/epoch - 4ms/step
# Epoch 41/100
# 77/77 - 0s - loss: 0.0030 - 299ms/epoch - 4ms/step
# Epoch 42/100
# 77/77 - 0s - loss: 0.0055 - 274ms/epoch - 4ms/step
# Epoch 43/100
# 77/77 - 0s - loss: 0.0041 - 271ms/epoch - 4ms/step
# Epoch 44/100
# 77/77 - 0s - loss: 0.0047 - 276ms/epoch - 4ms/step
# Epoch 45/100
# 77/77 - 0s - loss: 0.0050 - 292ms/epoch - 4ms/step
# Epoch 46/100
# 77/77 - 0s - loss: 0.0042 - 340ms/epoch - 4ms/step
# Epoch 47/100
# 77/77 - 0s - loss: 0.0041 - 313ms/epoch - 4ms/step
# Epoch 48/100
# 77/77 - 0s - loss: 0.0031 - 300ms/epoch - 4ms/step
# Epoch 49/100
# 77/77 - 0s - loss: 0.0032 - 299ms/epoch - 4ms/step
# Epoch 50/100
# 77/77 - 0s - loss: 0.0027 - 365ms/epoch - 5ms/step
# Epoch 51/100
# 77/77 - 0s - loss: 0.0046 - 302ms/epoch - 4ms/step
# Epoch 52/100
# 77/77 - 0s - loss: 0.0034 - 294ms/epoch - 4ms/step
# Epoch 53/100
# 77/77 - 0s - loss: 0.0035 - 300ms/epoch - 4ms/step
# Epoch 54/100
# 77/77 - 0s - loss: 0.0042 - 300ms/epoch - 4ms/step
# Epoch 55/100
# 77/77 - 0s - loss: 0.0037 - 303ms/epoch - 4ms/step
# Epoch 56/100
# 77/77 - 0s - loss: 0.0028 - 317ms/epoch - 4ms/step
# Epoch 57/100
# 77/77 - 0s - loss: 0.0033 - 292ms/epoch - 4ms/step
# Epoch 58/100
# 77/77 - 0s - loss: 0.0042 - 309ms/epoch - 4ms/step
# Epoch 59/100
# 77/77 - 0s - loss: 0.0048 - 300ms/epoch - 4ms/step
# Epoch 60/100
# 77/77 - 0s - loss: 0.0031 - 342ms/epoch - 4ms/step
# Epoch 61/100
# 77/77 - 0s - loss: 0.0032 - 307ms/epoch - 4ms/step
# Epoch 62/100
# 77/77 - 0s - loss: 0.0029 - 297ms/epoch - 4ms/step
# Epoch 63/100
# 77/77 - 0s - loss: 0.0028 - 298ms/epoch - 4ms/step
# Epoch 64/100
# 77/77 - 0s - loss: 0.0027 - 312ms/epoch - 4ms/step
# Epoch 65/100
# 77/77 - 0s - loss: 0.0032 - 317ms/epoch - 4ms/step
# Epoch 66/100
# 77/77 - 0s - loss: 0.0032 - 294ms/epoch - 4ms/step
# Epoch 67/100
# 77/77 - 0s - loss: 0.0039 - 299ms/epoch - 4ms/step
# Epoch 68/100
# 77/77 - 0s - loss: 0.0039 - 294ms/epoch - 4ms/step
# Epoch 69/100
# 77/77 - 0s - loss: 0.0031 - 307ms/epoch - 4ms/step
# Epoch 70/100
# 77/77 - 0s - loss: 0.0027 - 303ms/epoch - 4ms/step
# Epoch 71/100
# 77/77 - 0s - loss: 0.0035 - 282ms/epoch - 4ms/step
# Epoch 72/100
# 77/77 - 0s - loss: 0.0030 - 296ms/epoch - 4ms/step
# Epoch 73/100
# 77/77 - 0s - loss: 0.0050 - 294ms/epoch - 4ms/step
# Epoch 74/100
# 77/77 - 0s - loss: 0.0025 - 309ms/epoch - 4ms/step
# Epoch 75/100
# 77/77 - 0s - loss: 0.0034 - 308ms/epoch - 4ms/step
# Epoch 76/100
# 77/77 - 0s - loss: 0.0034 - 296ms/epoch - 4ms/step
# Epoch 77/100
# 77/77 - 0s - loss: 0.0038 - 308ms/epoch - 4ms/step
# Epoch 78/100
# 77/77 - 0s - loss: 0.0022 - 296ms/epoch - 4ms/step
# Epoch 79/100
# 77/77 - 0s - loss: 0.0027 - 263ms/epoch - 3ms/step
# Epoch 80/100
# 77/77 - 0s - loss: 0.0033 - 288ms/epoch - 4ms/step
# Epoch 81/100
# 77/77 - 0s - loss: 0.0040 - 310ms/epoch - 4ms/step
# Epoch 82/100
# 77/77 - 0s - loss: 0.0032 - 311ms/epoch - 4ms/step
# Epoch 83/100
# 77/77 - 0s - loss: 0.0036 - 307ms/epoch - 4ms/step
# Epoch 84/100
# 77/77 - 0s - loss: 0.0022 - 303ms/epoch - 4ms/step
# Epoch 85/100
# 77/77 - 0s - loss: 0.0027 - 297ms/epoch - 4ms/step
# Epoch 86/100
# 77/77 - 0s - loss: 0.0045 - 309ms/epoch - 4ms/step
# Epoch 87/100
# 77/77 - 0s - loss: 0.0031 - 315ms/epoch - 4ms/step
# Epoch 88/100
# 77/77 - 0s - loss: 0.0043 - 313ms/epoch - 4ms/step
# Epoch 89/100
# 77/77 - 0s - loss: 0.0025 - 315ms/epoch - 4ms/step
# Epoch 90/100
# 77/77 - 0s - loss: 0.0021 - 307ms/epoch - 4ms/step
# Epoch 91/100
# 77/77 - 0s - loss: 0.0034 - 316ms/epoch - 4ms/step
# Epoch 92/100
# 77/77 - 0s - loss: 0.0055 - 313ms/epoch - 4ms/step
# Epoch 93/100
# 77/77 - 0s - loss: 0.0034 - 294ms/epoch - 4ms/step
# Epoch 94/100
# 77/77 - 0s - loss: 0.0033 - 309ms/epoch - 4ms/step
# Epoch 95/100
# 77/77 - 0s - loss: 0.0032 - 298ms/epoch - 4ms/step
# Epoch 96/100
# 77/77 - 0s - loss: 0.0027 - 313ms/epoch - 4ms/step
# Epoch 97/100
# 77/77 - 0s - loss: 0.0029 - 317ms/epoch - 4ms/step
# Epoch 98/100
# 77/77 - 0s - loss: 0.0025 - 313ms/epoch - 4ms/step
# Epoch 99/100
# 77/77 - 0s - loss: 0.0023 - 316ms/epoch - 4ms/step
# Epoch 100/100
# 77/77 - 0s - loss: 0.0025 - 312ms/epoch - 4ms/step

# %%
predicted_closing_prices_scaled = model.predict(X)
# Out:
# 3/3 [==============================] - 2s 4ms/step

# %%
predicted_closing_prices = scaler.inverse_transform(predicted_closing_prices_scaled)
actual_closing_prices = scaler.inverse_transform(closing_prices_scaled[look_back:])

# %%
future_steps = 10
last_sequence = closing_prices_scaled[-look_back:]

# %%
future_predictions = []
for _ in range(future_steps):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred)[-look_back:].reshape(look_back, 1)

future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 85ms/step

# %%
plt.figure(figsize=(14, 7))
plt.plot(actual_closing_prices, label='Actual Closing Prices')
plt.plot(predicted_closing_prices, label='Predicted Closing Prices')
plt.plot(np.arange(len(actual_closing_prices), len(actual_closing_prices) + future_steps), future_predictions, label='Future Predictions', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Actual vs Predicted Closing Prices and Future Predictions (LSTM)')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(actual_closing_prices, predicted_closing_prices)
mae = mean_absolute_error(actual_closing_prices, predicted_closing_prices)
r2 = r2_score(actual_closing_prices, predicted_closing_prices)

print(f"MSE: {mse}")
print(f"MAE: {mae}")
print(f"R-squared: {r2}")
# Out:
# MSE: 22757.48752642221
# MAE: 108.55927851292994
# R-squared: 0.9834666583643805
