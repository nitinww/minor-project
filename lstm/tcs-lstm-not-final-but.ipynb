# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("../datasets/final/TCS.csv")

# %%
df.shape
# Out:
# (102, 84)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.set_index(df.columns[0], inplace=True)

# %%
# df = df.T

# %%
df
# Out:
#                                               Mar 4        Jun 4        Sep 4  \
# TCS
# Close                                     38.387501    87.250000   128.387497
# Equity Share Capital                      36.440000    36.440000    36.440000
# Total Share Capital                       36.440000    36.440000    36.440000
# Reserves and Surplus                      10.640000    10.640000    10.640000
# Total Reserves and Surplus                10.640000    10.640000    10.640000
# ...                                             ...          ...          ...
# P/L Before Tax                          7396.501515  7396.501515  7396.501515
# Tax                                       66.830000    66.830000    76.980000
# P/L After Tax from Ordinary Activities  5750.158788  5750.158788  5750.158788
# Net Profit/(Loss) For the Period         424.600000   424.600000   342.190000
# Equity Share Capital                      47.830000    47.830000    48.010000
#
#                                               Dec 4        Mar 5        Jun 5  \
# TCS
# Close                                    166.932495   179.007507   169.762497
# Equity Share Capital                      36.440000    48.010000    48.010000
# Total Share Capital                       36.440000    48.010000    48.010000
# Reserves and Surplus                      10.640000  3273.040000  3273.040000
# Total Reserves and Surplus                10.640000  3273.040000  3273.040000
# ...                                             ...          ...          ...
# P/L Before Tax                          7396.501515  7396.501515  7396.501515
# Tax                                       82.780000    53.910000    93.430000
# P/L After Tax from Ordinary Activities  5750.158788  5750.158788  5750.158788
# Net Profit/(Loss) For the Period         643.810000   426.700000   578.860000
# Equity Share Capital                      48.010000    48.010000    48.010000
#
#                                               Sep 5        Dec 5        Mar 6  \
# TCS
# Close                                    185.294998   212.857498   239.437500
# Equity Share Capital                      48.010000    48.010000    48.930000
# Total Share Capital                       48.010000    48.010000    48.930000
# Reserves and Surplus                    3273.040000  3273.040000  5560.400000
# Total Reserves and Surplus              3273.040000  3273.040000  5560.400000
# ...                                             ...          ...          ...
# P/L Before Tax                          7396.501515  7396.501515  7396.501515
# Tax                                       90.540000    88.340000    50.050000
# P/L After Tax from Ordinary Activities  5750.158788  5750.158788  5750.158788
# Net Profit/(Loss) For the Period         620.320000   679.650000   750.060000
# Equity Share Capital                      48.010000    48.010000    48.930000
#
#                                               Jun 6  ...        Mar 22  \
# TCS                                                  ...
# Close                                    217.345001  ...   3739.949951
# Equity Share Capital                      48.930000  ...    366.000000
# Total Share Capital                       48.930000  ...    366.000000
# Reserves and Surplus                    5560.400000  ...  76807.000000
# Total Reserves and Surplus              5560.400000  ...  76807.000000
# ...                                             ...  ...           ...
# P/L Before Tax                          7396.501515  ...  12626.000000
# Tax                                       79.410000  ...   2831.000000
# P/L After Tax from Ordinary Activities  5750.158788  ...   9795.000000
# Net Profit/(Loss) For the Period         796.690000  ...   9795.000000
# Equity Share Capital                      48.930000  ...    366.000000
#
#                                               Jun 22        Sep 22  \
# TCS
# Close                                    3267.100098   3004.550049
# Equity Share Capital                      366.000000    366.000000
# Total Share Capital                       366.000000    366.000000
# Reserves and Surplus                    76807.000000  76807.000000
# Total Reserves and Surplus              76807.000000  76807.000000
# ...                                              ...           ...
# P/L Before Tax                          11400.000000  13303.000000
# Tax                                      2812.000000   3244.000000
# P/L After Tax from Ordinary Activities   8588.000000  10059.000000
# Net Profit/(Loss) For the Period         8588.000000  10059.000000
# Equity Share Capital                      366.000000    366.000000
#
#                                               Dec 22        Mar 23    Jun 23  \
# TCS
# Close                                    3256.699951   3205.899902   3302.25
# Equity Share Capital                      366.000000    366.000000    366.00
# Total Share Capital                       366.000000    366.000000    366.00
# Reserves and Surplus                    76807.000000  74172.000000  74172.00
# Total Reserves and Surplus              76807.000000  74172.000000  74172.00
# ...                                              ...           ...       ...
# P/L Before Tax                          13942.000000  13045.000000  13932.00
# Tax                                      3283.000000   3245.000000   3448.00
# P/L After Tax from Ordinary Activities  10659.000000   9800.000000  10484.00
# Net Profit/(Loss) For the Period        10659.000000   9800.000000  10484.00
# Equity Share Capital                      366.000000    366.000000    366.00
#
#                                               Sep 23        Dec 23  \
# TCS
# Close                                    3528.600098   3793.399902
# Equity Share Capital                      366.000000    366.000000
# Total Share Capital                       366.000000    366.000000
# Reserves and Surplus                    74172.000000  74172.000000
# Total Reserves and Surplus              74172.000000  74172.000000
# ...                                              ...           ...
# P/L Before Tax                          14444.000000  14046.000000
# Tax                                      3515.000000   3293.000000
# P/L After Tax from Ordinary Activities  10929.000000  10753.000000
# Net Profit/(Loss) For the Period        10929.000000  10753.000000
# Equity Share Capital                      366.000000    362.000000
#
#                                               Mar 24        Jun 24
# TCS
# Close                                    3876.300049   3904.149902
# Equity Share Capital                      362.000000    362.000000
# Total Share Capital                       362.000000    362.000000
# Reserves and Surplus                    71758.000000  71758.000000
# Total Reserves and Surplus              71758.000000  71758.000000
# ...                                              ...           ...
# P/L Before Tax                          15180.000000  15878.000000
# Tax                                      3787.000000   3763.000000
# P/L After Tax from Ordinary Activities  11393.000000  12115.000000
# Net Profit/(Loss) For the Period        11393.000000  12115.000000
# Equity Share Capital                      362.000000    362.000000
#
# [102 rows x 82 columns]

# %%
closing_prices = df.iloc[0, 1:].values.astype(float)

scaler = MinMaxScaler(feature_range=(0, 1))
closing_prices_scaled = scaler.fit_transform(closing_prices.reshape(-1, 1))

# %%
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i+look_back])
        y.append(data[i+look_back])
    return np.array(X), np.array(y)

look_back = 9
X, y = create_sequences(closing_prices_scaled, look_back)

# %%
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 8s 2s/step - loss: 0.0820 - val_loss: 0.6047
# Epoch 2/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0493 - val_loss: 0.3931
# Epoch 3/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0259 - val_loss: 0.2162
# Epoch 4/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0140 - val_loss: 0.0879
# Epoch 5/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0135 - val_loss: 0.0327
# Epoch 6/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0176 - val_loss: 0.0256
# Epoch 7/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0150 - val_loss: 0.0345
# Epoch 8/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0104 - val_loss: 0.0539
# Epoch 9/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0076 - val_loss: 0.0755
# Epoch 10/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0073 - val_loss: 0.0875
# Epoch 11/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0074 - val_loss: 0.0838
# Epoch 12/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0075 - val_loss: 0.0676
# Epoch 13/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0063 - val_loss: 0.0453
# Epoch 14/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0044 - val_loss: 0.0278
# Epoch 15/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0032 - val_loss: 0.0240
# Epoch 16/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0039 - val_loss: 0.0317
# Epoch 17/50
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0045 - val_loss: 0.0373
# Epoch 18/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0040 - val_loss: 0.0350
# Epoch 19/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0032 - val_loss: 0.0311
# Epoch 20/50
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0033 - val_loss: 0.0276
# Epoch 21/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0032 - val_loss: 0.0267
# Epoch 22/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0039 - val_loss: 0.0266
# Epoch 23/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0035 - val_loss: 0.0282
# Epoch 24/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0034 - val_loss: 0.0311
# Epoch 25/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0035 - val_loss: 0.0317
# Epoch 26/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0033 - val_loss: 0.0290
# Epoch 27/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0034 - val_loss: 0.0256
# Epoch 28/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0033 - val_loss: 0.0238
# Epoch 29/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0031 - val_loss: 0.0239
# Epoch 30/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0032 - val_loss: 0.0244
# Epoch 31/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0033 - val_loss: 0.0237
# Epoch 32/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0033 - val_loss: 0.0230
# Epoch 33/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0032 - val_loss: 0.0227
# Epoch 34/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0032 - val_loss: 0.0227
# Epoch 35/50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0033 - val_loss: 0.0228
# Epoch 36/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0036 - val_loss: 0.0226
# Epoch 37/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0032 - val_loss: 0.0226
# Epoch 38/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0032 - val_loss: 0.0228
# Epoch 39/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0030 - val_loss: 0.0227
# Epoch 40/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0035 - val_loss: 0.0226
# Epoch 41/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0032 - val_loss: 0.0229
# Epoch 42/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0033 - val_loss: 0.0229
# Epoch 43/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0034 - val_loss: 0.0225
# Epoch 44/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0031 - val_loss: 0.0223
# Epoch 45/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0031 - val_loss: 0.0222
# Epoch 46/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0028 - val_loss: 0.0222
# Epoch 47/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0033 - val_loss: 0.0218
# Epoch 48/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0030 - val_loss: 0.0217
# Epoch 49/50
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0030 - val_loss: 0.0215
# Epoch 50/50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0030 - val_loss: 0.0214

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

# %%
y_train_scaled = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
full_closing_prices = scaler.inverse_transform(closing_prices_scaled)
all_predictions = np.concatenate([train_predictions, test_predictions], axis=0)

# %%
future_predictions = []
last_sequence = closing_prices_scaled[-look_back:]

# %%
num_future_predictions = 4
for _ in range(num_future_predictions):
    next_pred = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_pred[0, 0])
    last_sequence = np.append(last_sequence[1:], next_pred).reshape(look_back, 1)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
extended_predictions = np.concatenate([all_predictions, future_predictions])

# %%
plt.figure(figsize=(8,4))
plt.plot(full_closing_prices, color='blue', label='Observed Closing Prices')
plt.plot(np.arange(look_back, look_back + len(train_predictions)), train_predictions, color='orange', label='Train Predictions')
plt.plot(np.arange(look_back + len(train_predictions), look_back + len(train_predictions) + len(test_predictions)), test_predictions, color='red', label='Test Predictions')
plt.plot(np.arange(len(full_closing_prices), len(full_closing_prices) + num_future_predictions), future_predictions, color='green', linestyle='--', label='Future Predictions')
plt.axvline(x=len(full_closing_prices) - len(test_predictions), color='green', linestyle='--', label='Prediction Start')
plt.title('Closing Price Prediction with Future Points')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y_test_scaled, test_predictions)
mse = mean_squared_error(y_test_scaled, test_predictions)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test_scaled - test_predictions) / y_test_scaled)) * 100

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Mean Absolute Error (MAE): 479.2292805989583
# Mean Squared Error (MSE): 311633.68738987844
# Root Mean Squared Error (RMSE): 558.2416030625794
# Mean Absolute Percentage Error (MAPE): 14.208627253445366%
