# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/WIPRO.csv")

# %%
df.shape
# Out:
# (104, 84)

# %%
df
# Out:
#      Unnamed: 0.1                              Unnamed: 0        Mar 4  \
# 0               0                                   Close    51.045002
# 1               3                    Equity Share Capital    46.550000
# 2               4                     Total Share Capital    46.550000
# 3               5                    Reserves and Surplus  3461.040000
# 4               6              Total Reserves and Surplus  3461.040000
# ..            ...                                     ...          ...
# 99            135                          P/L Before Tax  2341.161765
# 100           136                                     Tax    74.400000
# 101           137  P/L After Tax from Ordinary Activities  1829.364706
# 102           140        Net Profit/(Loss) For the Period   259.000000
# 103           141                    Equity Share Capital    46.600000
#
#            Jun 4        Sep 4        Dec 4        Mar 5        Jun 5  \
# ...

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#                                  Unnamed: 0        Mar 4        Jun 4  \
# 0                                     Close    51.045002    59.861252
# 1                      Equity Share Capital    46.550000    46.550000
# 2                       Total Share Capital    46.550000    46.550000
# 3                      Reserves and Surplus  3461.040000  3461.040000
# 4                Total Reserves and Surplus  3461.040000  3461.040000
# ..                                      ...          ...          ...
# 99                           P/L Before Tax  2341.161765  2341.161765
# 100                                     Tax    74.400000    59.800000
# 101  P/L After Tax from Ordinary Activities  1829.364706  1829.364706
# 102        Net Profit/(Loss) For the Period   259.000000   326.800000
# 103                    Equity Share Capital    46.600000   139.700000
#
#            Sep 4        Dec 4        Mar 5        Jun 5        Sep 5  \
# ...

# %%
df.set_index(df.columns[0], inplace=True)

# %%
df
# Out:
#                                               Mar 4        Jun 4        Sep 4  \
# Unnamed: 0
# Close                                     51.045002    59.861252    67.139999
# Equity Share Capital                      46.550000    46.550000    46.550000
# Total Share Capital                       46.550000    46.550000    46.550000
# Reserves and Surplus                    3461.040000  3461.040000  3461.040000
# Total Reserves and Surplus              3461.040000  3461.040000  3461.040000
# ...                                             ...          ...          ...
# P/L Before Tax                          2341.161765  2341.161765  2341.161765
# Tax                                       74.400000    59.800000    66.700000
# P/L After Tax from Ordinary Activities  1829.364706  1829.364706  1829.364706
# Net Profit/(Loss) For the Period         259.000000   326.800000   370.100000
# Equity Share Capital                      46.600000   139.700000   139.800000
#
# ...

# %%
df.to_csv("./datasets/final/WIPRO.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/cash-flow/WIPRO-cash-flow.csv")
# Out:
# (21, 10)

# %%
df = df.T

# %%
df
# Out:
#                                                          0        1        2   \
# 0                                                    Mar 04   Mar 05   Mar 06
# Net Profit/Loss Before Extraordinary Items And Tax  1082.27  1757.02  2340.43
# Net CashFlow From Operating Activities               913.91  1666.42  1912.25
# Net Cash Used In Investing Activities              -1062.09  -874.58 -1694.42
# Net Cash Used From Financing Activities               28.57  -550.61     59.8
# Foreign Exchange Gains / Losses                         0.0      0.0      0.0
# Adjustments On Amalgamation Merger Demerger Others      0.0      0.0      0.0
# Net Inc/Dec In Cash And Cash Equivalents            -119.61    246.8   277.63
# Cash And Cash Equivalents Begin of Year               409.7   290.09   545.38
# Cash And Cash Equivalents End Of Year                290.09    536.9    823.0
#
#                                                         3       4       5   \
# ...
